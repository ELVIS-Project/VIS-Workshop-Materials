# %% [markdown]
# # 4. Processing Multiple Files

# %% [markdown]
# We can actually pass a series of files to the ```Importer()``` method, and thereby index many pieces at once:

# %%
import music21, pandas

# All we need is the Importer() method.
from vis.models.indexed_piece import Importer

# Specifying a file directory from which to choose symbolic music scores.
# Caveat: Only symbolic music score formats can be in the folder, any 
#         other file may cause the Importer() method to fail.
monophonic_files = ('scores/monophonic/symbolic/')

# Passing the folder to the Importer() method:
chants = Importer(monophonic_files)

# Calculating all intervals of all the chants contained in the folder: 
chants_hints = chants.get_data('horizontal_interval')

# Sanity Checking if the our actions were successful:
chants_hints
# Out:
# [Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                    -P4
#  2.0                                     M2
#  3.0                                     P1
#  4.0                                     P5
#  5.0                                     m2
#  6.0                                    -m2
#  7.0                                     P1
#  8.0                                    -M2
#  9.0                                    -M2
#  10.0                                    M2
#  11.0                                    M2
#  12.0                                    P1
#  13.0                                   -M2
#  14.0                                   -M2
#  15.0                                    M2
#  16.0                                   -P4
#  17.0                                    P4
#  18.0                                    P1
#  19.0                                    M2
#  20.0                                   -M2
#  21.0                                   -M2
#  22.0                                   -m2
#  23.0                                    m2
#  24.0                                    M2
#  25.0                                   -M2
#  26.0                                   -m2
#  27.0                                   -M2
#  28.0                                   -M2
#  29.0                                    M2
#  30.0                                    P1
#  31.0                                    P4
#  32.0                                   -M2
#  33.0                                    M2
#  34.0                                    M2
#  35.0                                   -M2
#  36.0                                   -M2
#  37.0                                   -m2
#  38.0                                    m2
#  39.0                                    M2
#  40.0                                   -M2
#  41.0                                   -m2
#  42.0                                   -M2
#  43.0                                    P1,
#  Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                     M2
#  2.0                                     M2
#  3.0                                     P1
#  4.0                                     P1
#  5.0                                     P1
#  6.0                                     P1
#  7.0                                     P1
#  8.0                                     P1
#  9.0                                     m3
#  10.0                                   -M2
#  11.0                                   -m2
#  12.0                                    P1
#  13.0                                   -M2
#  14.0                                    P1
#  15.0                                    M2
#  16.0                                    P1
#  17.0                                    P1
#  18.0                                    P1
#  19.0                                    P1
#  20.0                                    P1
#  21.0                                    m3
#  22.0                                   -M2
#  23.0                                   -m2
#  24.0                                    P1
#  25.0                                    P1
#  26.0                                    P1
#  27.0                                    P1
#  28.0                                    P1
#  29.0                                    P1
#  30.0                                    P1
#  31.0                                    P1
#  32.0                                   -M2
#  33.0                                   -P4
#  34.0                                    m3
#  35.0                                   -m2
#  36.0                                   -M2,
#  Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                    -m3
#  2.0                                     m2
#  3.0                                    -m3
#  4.0                                     M2
#  5.0                                     m3
#  6.0                                     M2
#  7.0                                     P1
#  8.0                                     m2
#  9.0                                    -m2
#  10.0                                    P1
#  11.0                                   -M2
#  12.0                                   -M2
#  13.0                                    M2
#  14.0                                    P1
#  15.0                                   -m3
#  16.0                                    m2
#  17.0                                    M2
#  18.0                                    P1
#  19.0                                    P1
#  20.0                                   -M2
#  21.0                                    M3
#  22.0                                   -M2
#  23.0                                    P1
#  24.0                                   -m3
#  25.0                                    m2
#  26.0                                    M2
#  27.0                                    P1
#  28.0                                    P1
#  29.0                                    P1
#  30.0                                   -M2
#  ...                                    ...
#  386.0                                   m2
#  387.0                                   M2
#  388.0                                   M2
#  389.0                                  -M3
#  390.0                                   M3
#  391.0                                  -M2
#  392.0                                   P1
#  393.0                                  -m3
#  394.0                                   m2
#  395.0                                   M2
#  396.0                                   P1
#  397.0                                   P1
#  398.0                                  -M2
#  399.0                                  -m2
#  400.0                                  -M2
#  401.0                                   P1
#  402.0                                   P5
#  403.0                                   m2
#  404.0                                  -m2
#  405.0                                   P1
#  406.0                                 Rest
#  414.0                                 Rest
#  415.0                                  -M2
#  416.0                                  -M2
#  417.0                                   M2
#  418.0                                   M2
#  419.0                                  -M2
#  420.0                                  -M2
#  421.0                                  -m2
#  422.0                                  -M2
#
#  [415 rows x 1 columns],
#  Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                     M2
#  2.0                                     M2
#  3.0                                     P1
#  4.0                                     P1
#  5.0                                     P1
#  6.0                                     m3
#  7.0                                    -m3
#  8.0                                     P1
#  9.0                                    -M2
#  10.0                                   -P4
#  11.0                                    m3
#  12.0                                    P1
#  13.0                                   -m2
#  14.0                                   -M2
#  15.0                                    P5
#  16.0                                    m3
#  17.0                                   -m3
#  18.0                                    m2
#  19.0                                   -m3
#  20.0                                   -M2
#  21.0                                    M2
#  22.0                                    P1
#  23.0                                   -M2
#  24.0                                   -m2
#  25.0                                   -M2,
#  Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                     M2
#  2.0                                     m3
#  3.0                                     P1
#  4.0                                     M2
#  5.0                                     P1
#  6.0                                     M2
#  7.0                                     m2
#  8.0                                    -m2
#  9.0                                    -M2
#  10.0                                   -M2
#  11.0                                    M2
#  12.0                                    M2
#  13.0                                    P1
#  14.0                                   -M2
#  15.0                                    M2
#  16.0                                    m3
#  17.0                                   -m3
#  18.0                                    P1
#  19.0                                    P1
#  20.0                                    P1
#  21.0                                    P1
#  22.0                                    P1
#  23.0                                    m2
#  24.0                                   -m2
#  25.0                                   -M2
#  26.0                                   -M2
#  27.0                                    M2
#  28.0                                    M2
#  29.0                                    P1
#  30.0                                    P1
#  31.0                                    P1
#  32.0                                    P1
#  33.0                                   -M2
#  34.0                                   -P4
#  35.0                                    m3
#  36.0                                    P1
#  37.0                                   -m2
#  38.0                                   -M2
#  39.0                                    P5
#  40.0                                    m2
#  41.0                                   -m3
#  42.0                                   -M2
#  43.0                                    M2
#  44.0                                    P1
#  45.0                                   -M2
#  46.0                                   -m2
#  47.0                                   -M2,
#  Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0
#  1.0                                     m3
#  2.0                                     M2
#  3.0                                     P1
#  4.0                                     M2
#  5.0                                    -M2
#  6.0                                     P1
#  7.0                                    -M2
#  8.0                                     M2
#  9.0                                     P1
#  10.0                                   -M2
#  11.0                                    P1
#  12.0                                    P1
#  13.0                                    M2
#  14.0                                    P1
#  15.0                                   -M2
#  16.0                                    M2
#  17.0                                    P1
#  18.0                                   -P4
#  19.0                                    m3
#  20.0                                    M2
#  21.0                                    P1
#  22.0                                    P1
#  23.0                                    P1
#  24.0                                    P1
#  25.0                                    P1
#  26.0                                    P1
#  27.0                                   -M2
#  28.0                                    P1
#  29.0                                    P1
#  30.0                                    M2
#  ...                                    ...
#  126.0                                   M2
#  127.0                                  -M2
#  128.0                                  -M2
#  129.0                                   M2
#  130.0                                   P1
#  131.0                                  -P4
#  132.0                                   m3
#  133.0                                   M2
#  134.0                                   P1
#  135.0                                   M2
#  136.0                                  -M2
#  137.0                                   P1
#  138.0                                   P1
#  139.0                                  -M2
#  140.0                                   M2
#  141.0                                   P1
#  142.0                                  -M2
#  143.0                                   P1
#  144.0                                   P1
#  145.0                                   M2
#  146.0                                   P1
#  147.0                                   P1
#  148.0                                  -M2
#  149.0                                   M2
#  150.0                                   M2
#  151.0                                  -M2
#  152.0                                  -M2
#  153.0                                  -m3
#  154.0                                   P1
#  155.0                                   P1
#
#  [155 rows x 1 columns]]

# %%
# Checking how many chants we have processed just now:
len(chants_hints)
# Out:
# 6

# %% [markdown]
# We have successfully extracted the horizontal interval data, but how to proceed next? Here is a small preview:

# %%
# Putting all horizontal intervals in the chants into one DataFrame:
chants_hints_all = pandas.concat(chants_hints)

# chants_hints_all

# %%
# Same process, but now with polyphonic music
polyphonic_files = ('scores/polyphonic/symbolic')

masses_motets = Importer(polyphonic_files)
masses_motets_hints = masses_motets.get_data('horizontal_interval')

masses_motets_hints
# Out:
# [Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1     2     3
#  4.0                                    -m2    M2    m3   -M2
#  6.0                                     P1    P1   NaN    P1
#  7.0                                    NaN   NaN   -M2   NaN
#  8.0                                    -M3   -M2   -m2   -P5
#  9.5                                    NaN    M2   NaN   NaN
#  10.0                                    M2    M2   NaN   NaN
#  11.0                                   NaN    m2   -M2    M2
#  12.0                                    M2   NaN   NaN   NaN
#  13.0                                   NaN   -m3    m3   NaN
#  14.0                                    m2    M2   -m2   -M2
#  15.0                                   NaN   -M3   NaN    P8
#  16.0                                   -P4    P5   NaN   NaN
#  17.0                                    P4   NaN   -M2   -m2
#  17.5                                   NaN   NaN   -M2   -M2
#  18.0                                   NaN  Rest    M2   -M2
#  19.0                                   -m2  Rest   NaN   NaN
#  20.0                                    m2   -m3   -M2    M2
#  21.0                                   -m3    m2   NaN   -M3
#  22.0                                   -M2    M2   NaN   -m2
#  23.0                                    M2   -M2   NaN    m2
#  24.0                                   -M2   -m2  Rest   -P4
#  25.0                                   NaN   -M3   NaN    P8
#  26.0                                  Rest    P8  Rest   NaN
#  26.5                                   NaN   NaN   NaN   -m2
#  27.0                                  Rest   -m2   NaN   -M3
#  28.0                                   -m3   -M2    P4    M2
#  29.0                                    m2   NaN   NaN   -M3
#  30.0                                   -m3   -M2   -m2    M2
#  31.0                                    m3    P4   -M2   -M2
#  32.5                                   -m2   NaN   NaN   NaN
#  ...                                    ...   ...   ...   ...
#  249.0                                  -m2   -m3   NaN   -P4
#  250.0                                  NaN    m2  Rest    M2
#  251.0                                  -M2   NaN   NaN   NaN
#  252.0                                   M2   -m2    m3    P5
#  253.0                                  NaN   NaN   NaN    m3
#  254.0                                  NaN  Rest   NaN   NaN
#  255.0                                  -M2  Rest    M2   -m2
#  256.0                                  -M2   -m3    M2   -M2
#  257.0                                  NaN   -M3    m2   NaN
#  258.0                                  -m2    M2    M2   -M2
#  259.0                                   m3   NaN   NaN   NaN
#  260.0                                  -P5   -M2   NaN    P4
#  261.0                                   M2    P8   NaN   NaN
#  262.0                                  NaN   -m3   -M2    M2
#  263.0                                   M2   -M3   NaN   NaN
#  264.0                                   m2    M2   -m2   -M2
#  266.0                                 Rest   -M2    P4   -P5
#  267.0                                 Rest   NaN   NaN   NaN
#  268.0                                  -m2  Rest   -P4  Rest
#  269.0                                   m2  Rest   NaN  Rest
#  270.0                                  -m2   -M2   -M2    M2
#  271.0                                   m2   -m2    M2   -M2
#  272.0                                  NaN    m3   NaN   NaN
#  272.5                                  -m2   NaN   NaN   NaN
#  273.0                                  -M2   -M2   -M2    M2
#  273.5                                  NaN   NaN   -M2   NaN
#  274.0                                  NaN   -m2   -m2    M2
#  275.0                                  -m2   NaN   NaN   NaN
#  276.0                                   m2    P1   -M2    P4
#  280.0                                  NaN   NaN   NaN   -P8
#
#  [296 rows x 4 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1     2
#  2.00                                   NaN   NaN  Rest
#  4.00                                  Rest  Rest    m2
#  5.50                                   NaN   NaN   -m2
#  6.00                                   NaN   NaN    m2
#  7.00                                   NaN   NaN   -m2
#  8.00                                  Rest  Rest   NaN
#  8.50                                   NaN   NaN   -M2
#  9.00                                   NaN   NaN   -M2
#  9.50                                   NaN   NaN   -m2
#  10.00                                  NaN   NaN   -M2
#  10.50                                  NaN   NaN    M2
#  11.00                                  NaN   NaN    m2
#  11.50                                  NaN   NaN    M2
#  12.00                                 Rest  Rest    M2
#  13.00                                  NaN   NaN   -M2
#  14.00                                 Rest   NaN   NaN
#  15.00                                  NaN   NaN   -m2
#  16.00                                   m2  Rest    m2
#  17.50                                  -m2   NaN   NaN
#  18.00                                   m2   NaN   -P4
#  19.00                                  -m2   NaN    m3
#  20.00                                  NaN  Rest   NaN
#  20.50                                  -M2   NaN   -m2
#  21.00                                  -M2   NaN   -M2
#  21.50                                  -m2   NaN   -M2
#  22.00                                  -M2   NaN   -M2
#  22.50                                   M2   NaN   NaN
#  23.00                                   m2   NaN    M3
#  23.50                                   M2   NaN   NaN
#  24.00                                   M2  Rest   -M2
#  ...                                    ...   ...   ...
#  199.00                                 -M2   NaN    M2
#  199.50                                 -M2   NaN   NaN
#  200.00                                  M2  Rest    m2
#  201.00                                  M2   NaN    M2
#  202.00                                 -P5   NaN   -m3
#  203.00                                  P5   NaN   NaN
#  203.50                                 NaN   NaN    m2
#  204.00                                 -M3  Rest    M2
#  205.00                                 -m3   NaN    M2
#  206.00                                  M2   NaN   NaN
#  207.00                                 NaN   NaN   -M2
#  208.00                                 -M2  Rest    M2
#  209.50                                  M2   NaN   NaN
#  210.00                                  m2   NaN   -M2
#  210.50                                  M2   NaN   NaN
#  211.00                                  M2   -M2   NaN
#  211.50                                 NaN   -M2   -M2
#  211.75                                 NaN   NaN   -m2
#  212.00                                  m2    M2   -M2
#  213.00                                  M2    M2   -M2
#  214.00                                 -m3   -P5   NaN
#  214.50                                 NaN   NaN   -m2
#  214.75                                 NaN   NaN   -M2
#  215.00                                 NaN    P5   -M2
#  215.50                                  m2   NaN   -M2
#  216.00                                  M2   -M3   -m2
#  217.00                                  M2   -m3    m2
#  218.00                                 NaN    M2   -m2
#  219.00                                 -m2   NaN   NaN
#  220.00                                  m2   -M2   -P5
#
#  [252 rows x 3 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1     2
#  4.0                                   Rest    m2   -M2
#  6.0                                    NaN    M2   -M2
#  7.0                                    NaN    M2   NaN
#  8.0                                   Rest   NaN    P4
#  9.0                                    NaN   -M2   NaN
#  9.5                                    NaN   -M2   NaN
#  10.0                                  Rest    M2   -m2
#  12.0                                   NaN    M2  Rest
#  13.0                                   NaN   NaN  Rest
#  14.0                                   -P5  Rest   NaN
#  14.5                                   NaN   NaN    M2
#  15.0                                   NaN   NaN    m2
#  15.5                                    M2   NaN    M2
#  16.0                                    m2  Rest    M2
#  16.5                                    M2   NaN   NaN
#  17.0                                    M2  Rest   -M3
#  18.0                                   NaN   NaN    P4
#  19.0                                   -M2    P1   NaN
#  19.5                                   NaN   NaN    M2
#  20.0                                    m3   -P5    M2
#  20.5                                   NaN    M2   NaN
#  21.0                                   NaN    m2   NaN
#  21.5                                   NaN    M2   NaN
#  22.0                                   -m2    M2   NaN
#  22.5                                   NaN    M2   NaN
#  23.0                                   NaN    m2   NaN
#  24.0                                   NaN   NaN  Rest
#  25.0                                   NaN   -m2  Rest
#  26.0                                   NaN    m2   -P5
#  27.5                                   NaN   -m2    M2
#  ...                                    ...   ...   ...
#  269.0                                  -m2   NaN   -M2
#  270.0                                  NaN   NaN    M2
#  270.5                                  -M2   NaN   NaN
#  271.0                                   P1   NaN   NaN
#  272.0                                  NaN   NaN   -P4
#  273.0                                  -M2   NaN   NaN
#  273.5                                  -m2   NaN   NaN
#  274.0                                   m2   NaN  Rest
#  275.0                                  -P5   NaN  Rest
#  275.5                                   M2   NaN   NaN
#  276.0                                   M2   NaN   NaN
#  276.5                                  -M2   NaN   NaN
#  277.0                                   M2   NaN    P1
#  277.5                                   M2   NaN   NaN
#  278.0                                   m2   NaN   -M2
#  278.5                                   M2   NaN   NaN
#  279.0                                   M2   NaN   NaN
#  280.0                                   m2   NaN    M2
#  281.5                                  -m2   NaN   NaN
#  282.0                                  -M2   NaN    m3
#  283.0                                  -M2   NaN   NaN
#  283.5                                  NaN   NaN   -m2
#  284.0                                   P4   NaN   -M2
#  285.0                                  -m2   NaN   -M2
#  286.0                                  NaN   NaN    M2
#  287.0                                  -M2   NaN   NaN
#  288.0                                  NaN   NaN   -P4
#  289.0                                  -M2   NaN   NaN
#  289.5                                  -m2   NaN   NaN
#  290.0                                   m2   NaN   NaN
#
#  [361 rows x 3 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1
#  4.0                                   Rest    m2
#  6.0                                   Rest    M2
#  7.0                                    NaN   -m3
#  9.0                                    NaN   -M3
#  10.0                                    m2    M2
#  12.0                                    M2   -M2
#  13.0                                   -m3   NaN
#  14.0                                   NaN  Rest
#  15.0                                   -M3  Rest
#  16.0                                    M2   NaN
#  17.0                                   NaN   -m2
#  18.0                                   -M2    m2
#  19.0                                   NaN   -m3
#  20.0                                  Rest   NaN
#  21.0                                  Rest   -M2
#  21.5                                   NaN   -M2
#  22.0                                   NaN   -m2
#  23.0                                   -m2   -M2
#  24.0                                    m2    P5
#  25.0                                   -m3   NaN
#  26.0                                   NaN   -M3
#  27.0                                   -M2   NaN
#  27.5                                   -M2   NaN
#  28.0                                   -m2    M2
#  29.0                                   -M2   NaN
#  30.0                                    P5   -M2
#  32.0                                   -M3  Rest
#  33.0                                   NaN  Rest
#  34.0                                    M2    M2
#  35.5                                   NaN    m2
#  ...                                    ...   ...
#  191.0                                   M2  Rest
#  192.0                                   m2    M2
#  193.0                                   M2    M2
#  194.0                                  -m3   NaN
#  195.0                                  NaN   -M3
#  196.0                                 Rest    M2
#  197.0                                 Rest    M2
#  198.0                                   M2    m2
#  199.0                                   M2    M2
#  200.0                                  NaN   -m3
#  201.0                                  -M3   NaN
#  202.0                                   M2  Rest
#  203.0                                   M2  Rest
#  204.0                                   m2    M2
#  205.0                                   M2    M2
#  206.0                                  -m3   NaN
#  207.0                                  NaN   -M3
#  208.0                                 Rest    M2
#  209.0                                 Rest    M2
#  210.0                                   M2    m2
#  211.0                                   M2    M2
#  212.0                                  NaN   -m3
#  213.0                                  -M3   NaN
#  214.0                                   M2   -M2
#  215.0                                   M2   -M2
#  215.5                                  NaN   -M2
#  216.0                                   m2   -m2
#  217.0                                   M2   -M2
#  218.0                                  -m3    M2
#  220.0                                  -M2   -P5
#
#  [208 rows x 2 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1     2
#  4.0                                    -M2    m3  Rest
#  6.0                                     P1   NaN   NaN
#  7.0                                    NaN   -m2   NaN
#  8.0                                     P4   -M2  Rest
#  10.0                                   NaN   -M2   NaN
#  11.0                                   -m2   NaN   NaN
#  12.0                                   -M2    P4  Rest
#  14.0                                    P1    M2   NaN
#  16.0                                   -M2    M2  Rest
#  17.5                                   NaN   -M2   NaN
#  18.0                                   NaN   -M2   NaN
#  18.5                                   NaN   -m2   NaN
#  19.0                                   NaN    P4   NaN
#  20.0                                  Rest   NaN   NaN
#  21.0                                   NaN   -M2   NaN
#  21.5                                   NaN   -M2   NaN
#  22.0                                  Rest   -m2   NaN
#  24.0                                   NaN  Rest    P1
#  25.0                                    M2   NaN   NaN
#  26.0                                    M2  Rest   NaN
#  27.0                                    m2   NaN   NaN
#  28.0                                   NaN   -M3    m2
#  28.5                                   -m3   NaN   NaN
#  29.0                                    m3   NaN   NaN
#  30.0                                   NaN    M2    P1
#  31.0                                   -m2   NaN   NaN
#  31.5                                   -M2   NaN   NaN
#  32.0                                   -M2    M2   -m2
#  35.0                                   NaN   -M2   NaN
#  35.5                                   NaN   -M2   NaN
#  ...                                    ...   ...   ...
#  152.0                                   m2   -M2    M2
#  153.0                                  NaN    M2   NaN
#  153.5                                  NaN    M2   NaN
#  154.0                                  NaN    m2   NaN
#  155.0                                  NaN   -m2   -M2
#  156.0                                 Rest   NaN   -M2
#  157.0                                  NaN   -M2   NaN
#  158.0                                 Rest    M2   -m2
#  160.0                                   M2  Rest    m2
#  161.0                                  NaN  Rest   NaN
#  161.5                                   M2   NaN   NaN
#  162.0                                   m2   NaN   NaN
#  162.5                                  NaN    M2   NaN
#  163.0                                  -m3    m2   NaN
#  164.0                                  NaN    M2   -m3
#  165.0                                   P4    m3   NaN
#  166.5                                  -M2   -m2   NaN
#  167.0                                  -m2   -M2   NaN
#  167.5                                  -M2   -M2   NaN
#  168.0                                  -M2   -m2    M2
#  169.0                                  NaN    m2   NaN
#  169.5                                   M2   NaN   NaN
#  170.0                                   M2   -m2   NaN
#  171.0                                   m2    P4   NaN
#  172.0                                  -m2   NaN   NaN
#  172.5                                  NaN   -M2   NaN
#  173.0                                  -M2   -M2   NaN
#  174.0                                  NaN   -m2   NaN
#  175.0                                  -m2   NaN   NaN
#  176.0                                   m2   -M2   -P5
#
#  [165 rows x 3 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1
#  6.0                                    -M2   NaN
#  8.0                                     M2  Rest
#  10.0                                   -M3   NaN
#  12.0                                    M2   NaN
#  14.0                                    M2   NaN
#  16.0                                   NaN  Rest
#  17.0                                   -M2   NaN
#  18.0                                   -M2   NaN
#  19.0                                   -m2   NaN
#  20.0                                   -M2   NaN
#  22.0                                    M2   -M2
#  24.0                                   -P5    M2
#  26.0                                   NaN   -M3
#  28.0                                  Rest    M2
#  30.0                                   NaN    M2
#  32.0                                  Rest   NaN
#  33.0                                   NaN   -M2
#  34.0                                   NaN   -M2
#  35.0                                   NaN   -m2
#  36.0                                   NaN   -M2
#  38.0                                   -M2    M2
#  40.0                                    M2   -P5
#  42.0                                   -M3   NaN
#  44.0                                    M2  Rest
#  46.0                                    M2   NaN
#  48.0                                   -M3  Rest
#  50.0                                    P5   NaN
#  53.0                                   -m3   NaN
#  54.0                                    M2   -M2
#  56.0                                    m2    M2
#  ...                                    ...   ...
#  216.0                                   M2   -M2
#  218.0                                   m2   -m3
#  220.0                                  NaN    m2
#  222.0                                  -m2   NaN
#  223.0                                  -M2   NaN
#  224.0                                  -M2   -m2
#  226.0                                  -M2    m6
#  228.0                                   M3   NaN
#  230.0                                  NaN   -m2
#  231.0                                  NaN   -M2
#  232.0                                  -M2    M2
#  234.0                                  -M2    m2
#  236.0                                   P5   NaN
#  238.0                                  NaN   -m2
#  239.0                                  NaN   -M2
#  240.0                                  -m2   -M2
#  242.0                                  -M2   -M2
#  244.0                                  NaN    M3
#  246.0                                  -M2   NaN
#  247.0                                  -M2   NaN
#  248.0                                  -m2   -M2
#  250.0                                   m6   -M2
#  252.0                                  NaN    P5
#  253.0                                  -m2   NaN
#  254.0                                  -M2   NaN
#  256.0                                  -M2   -m2
#  258.0                                  -M2   -M2
#  262.0                                  -m2   -M2
#  263.0                                  -M2   -M2
#  264.0                                  -M2   -m2
#
#  [141 rows x 2 columns], Indexer interval.HorizontalIntervalIndexer
#  Parts                                    0     1
#  4.0                                     P1   NaN
#  8.0                                    NaN  Rest
#  10.0                                   -M2   NaN
#  11.0                                   -M2   NaN
#  12.0                                    M3   NaN
#  14.0                                   -M2   NaN
#  16.0                                   NaN  Rest
#  17.0                                   -M2   NaN
#  18.0                                   -m2   NaN
#  19.0                                   -M2   NaN
#  20.0                                   -M2    P1
#  24.0                                  Rest   NaN
#  26.0                                  Rest   -M2
#  27.0                                   NaN   -M2
#  28.0                                   NaN    M3
#  30.0                                   -M2   -M2
#  32.0                                    M3   NaN
#  33.0                                   NaN   -M2
#  34.0                                   -M2   -m2
#  35.0                                   NaN   -M2
#  36.0                                   NaN   -M2
#  38.0                                   -M2   NaN
#  39.0                                   -m2   NaN
#  40.0                                   -M2  Rest
#  42.0                                   NaN  Rest
#  44.0                                    P5   NaN
#  46.0                                   NaN   -M2
#  48.0                                   -M2    M3
#  50.0                                   -M2   -M2
#  54.0                                   -m2   -M2
#  ...                                    ...   ...
#  184.0                                  -m2   -M2
#  186.0                                  -M2    M2
#  188.0                                   P5   -P4
#  192.0                                  -M2    P5
#  196.0                                  NaN   -M2
#  198.0                                   M2   -M2
#  200.0                                  -M2   -m2
#  202.0                                   M2   -M2
#  204.0                                  NaN    P5
#  205.0                                  -M2   NaN
#  206.0                                  -m3   NaN
#  208.0                                   m2   -M2
#  212.0                                   M2   NaN
#  214.0                                  NaN    M2
#  216.0                                  -M2   -M2
#  218.0                                   M2    M2
#  221.0                                  -M2   -M2
#  222.0                                  -m3   -m3
#  224.0                                   M2    m2
#  228.0                                  -M2    M2
#  229.0                                   M2   NaN
#  230.0                                   m2   NaN
#  231.0                                   M2   NaN
#  232.0                                   M2   -M2
#  234.0                                   M2    M2
#  237.0                                  -M2   -M2
#  238.0                                   P1   -m3
#  240.0                                  NaN    M2
#  242.0                                  -m2   NaN
#  244.0                                   m2   -M2
#
#  [132 rows x 2 columns]]

# %%
# Counting how many DataFrames with different pieces we have amassed:
len(masses_motets_hints)
# Out:
# 7

# %% [markdown]
# #### << [3_The_NGram_Indexer.ipynb](3_The_NGram_Indexer.ipynb) | [5_Data_Wrangling_Results.ipynb](5_Data_Wrangling_Results.ipynb) >>

# %% [markdown]
# - [1_Getting_Started_with_VIS.ipynb](1_Getting_Started_with_VIS.ipynb)
# - [2_Interval_Indexers.ipynb](2_Interval_Indexers.ipynb)
# - [3_The_NGram_Indexer.ipynb](3_The_NGram_Indexer.ipynb)
# - [4_Processing_Multiple_Files.ipynb](4_Processing_Multiple_Files.ipynb)
# - [5_Data_Wrangling_Results.ipynb](5_Data_Wrangling_Results.ipynb)
# - [6_Appendix.ipynb](6_Appendix.ipynb)
